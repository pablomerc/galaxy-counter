# %%
import glob
import os
import random
from typing import Iterable, List, Optional, Sequence, Tuple

import numpy as np
import torch
from datasets import load_dataset
dataset_path = '/data/vision/billf/scratch/pablomer/legacysurvey_hsc/data'
catalog_name = "legacysurvey_hsc_crossmatched"
files_to_use = 1
pattern = os.path.join(dataset_path, "*.parquet")
all_files = sorted(glob.glob(pattern))
dataset=load_dataset(
        "parquet",
        data_files=all_files,
        split="train"
    )
idx = 10
example_record = dataset[idx]

# print(example_record.keys() )
hsc_image = np.array(example_record['hsc_image']['flux'])
legacysurvey_image = np.array(example_record['legacysurvey_image']['flux'])

print(hsc_image.shape)
print(legacysurvey_image.shape)

hsc_image_tensor = torch.from_numpy(hsc_image).float()
legacysurvey_image_tensor = torch.from_numpy(legacysurvey_image).float()
print(hsc_image_tensor.shape)
print(legacysurvey_image_tensor.shape)


#Lets test the classes



import matplotlib.pyplot as plt
im1=hsc_image_tensor[1:4,:,:]
im2=legacysurvey_image_tensor[1:4,:,:]

#Normalize the rescaled one to 0-1

#do arcsinh of rescaled image

#original normalized
im1_normalized = (im1 - im1.min()) / (im1.max() - im1.min())
im2_normalized = (im2 - im2.min()) / (im2.max() - im2.min())

print('Range of original image: ', im1.min(), im1.max())


fig, axs = plt.subplots(2, 4, figsize=(15, 5))
axs[0,0].imshow(im1.numpy().transpose(1,2,0))
axs[0,0].set_title('Original')
axs[0,1].imshow(im1_normalized.numpy().transpose(1,2,0))
axs[0,2].set_title('Normalized')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[3], line 14
#      12 pattern = os.path.join(dataset_path, "*.parquet")
#      13 all_files = sorted(glob.glob(pattern))
# ---> 14 dataset=load_dataset(
#      15         "parquet",
#      16         data_files=all_files,
#      17         split="train"
#      18     )
#      19 idx = 10
#      20 example_record = dataset[idx]
#
# File /data/vision/billf/scratch/pablomer/miniconda3/envs/py310-torch/lib/python3.10/site-packages/datasets/load.py:1492, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1487 verification_mode = VerificationMode(
#    1488     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1489 )
#    1491 # Create a dataset builder
# -> 1492 builder_instance = load_dataset_builder(
#    1493     path=path,
#    1494     name=name,
#    1495     data_dir=data_dir,
#    1496     data_files=data_files,
#    1497     cache_dir=cache_dir,
#    1498     features=features,
#    1499     download_config=download_config,
#    1500     download_mode=download_mode,
#    1501     revision=revision,
#    1502     token=token,
#    1503     storage_options=storage_options,
#    1504     **config_kwargs,
#    1505 )
#    1507 # Return iterable dataset in case of streaming
#    1508 if streaming:
#
# File /data/vision/billf/scratch/pablomer/miniconda3/envs/py310-torch/lib/python3.10/site-packages/datasets/load.py:1171, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1169 builder_cls = get_dataset_builder_class(dataset_module, dataset_name=dataset_name)
#    1170 # Instantiate the dataset builder
# -> 1171 builder_instance: DatasetBuilder = builder_cls(
#    1172     cache_dir=cache_dir,
#    1173     dataset_name=dataset_name,
#    1174     config_name=config_name,
#    1175     data_dir=data_dir,
#    1176     data_files=data_files,
#    1177     hash=dataset_module.hash,
#    1178     info=info,
#    1179     features=features,
#    1180     token=token,
#    1181     storage_options=storage_options,
#    1182     **builder_kwargs,
#    1183     **config_kwargs,
#    1184 )
#    1185 builder_instance._use_legacy_cache_dir_if_possible(dataset_module)
#    1187 return builder_instance
#
# File /data/vision/billf/scratch/pablomer/miniconda3/envs/py310-torch/lib/python3.10/site-packages/datasets/builder.py:389, in DatasetBuilder.__init__(self, cache_dir, dataset_name, config_name, hash, base_path, info, features, token, repo_id, data_files, data_dir, storage_options, writer_batch_size, config_id, **config_kwargs)
#     385 os.makedirs(self._cache_dir_root, exist_ok=True)
#     386 lock_path = os.path.join(
#     387     self._cache_dir_root, Path(self._cache_dir).as_posix().replace("/", "_") + ".lock"
#     388 )
# --> 389 with FileLock(lock_path):
#     390     if os.path.exists(self._cache_dir):  # check if data exist
#     391         if len(os.listdir(self._cache_dir)) > 0:
#
# File /data/vision/billf/scratch/pablomer/miniconda3/envs/py310-torch/lib/python3.10/site-packages/filelock/_api.py:376, in BaseFileLock.__enter__(self)
#     369 def __enter__(self) -> Self:
#     370     """
#     371     Acquire the lock.
#     372
#     373     :return: the lock object
#     374
#     375     """
# --> 376     self.acquire()
#     377     return self
#
# File /data/vision/billf/scratch/pablomer/miniconda3/envs/py310-torch/lib/python3.10/site-packages/filelock/_api.py:332, in BaseFileLock.acquire(self, timeout, poll_interval, poll_intervall, blocking)
#     330 if not self.is_locked:
#     331     _LOGGER.debug("Attempting to acquire lock %s on %s", lock_id, lock_filename)
# --> 332     self._acquire()
#     333 if self.is_locked:
#     334     _LOGGER.debug("Lock %s acquired on %s", lock_id, lock_filename)
#
# File /data/vision/billf/scratch/pablomer/miniconda3/envs/py310-torch/lib/python3.10/site-packages/filelock/_unix.py:42, in UnixFileLock._acquire(self)
#      40 ensure_directory_exists(self.lock_file)
#      41 open_flags = os.O_RDWR | os.O_TRUNC
# ---> 42 if not Path(self.lock_file).exists():
#      43     open_flags |= os.O_CREAT
#      44 fd = os.open(self.lock_file, open_flags, self._context.mode)
#
# File /data/vision/billf/scratch/pablomer/miniconda3/envs/py310-torch/lib/python3.10/pathlib.py:1290, in Path.exists(self)
#    1286 """
#    1287 Whether this path exists.
#    1288 """
#    1289 try:
# -> 1290     self.stat()
#    1291 except OSError as e:
#    1292     if not _ignore_error(e):
#
# File /data/vision/billf/scratch/pablomer/miniconda3/envs/py310-torch/lib/python3.10/pathlib.py:1097, in Path.stat(self, follow_symlinks)
#    1092 def stat(self, *, follow_symlinks=True):
#    1093     """
#    1094     Return the result of the stat() system call on this path, like
#    1095     os.stat() does.
#    1096     """
# -> 1097     return self._accessor.stat(self, follow_symlinks=follow_symlinks)
#
# PermissionError: [Errno 13] Permission denied: '/afs/csail.mit.edu/u/p/pablomer/.cache/huggingface/datasets/_afs_csail.mit.edu_u_p_pablomer_.cache_huggingface_datasets_parquet_default-30e44cd01917c4ff_0.0.0_99544bb2c65d2b4bffc13f92abf8aabba034f3a5332697346ebc2b1d0fa3ee73.lock'
